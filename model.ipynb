# %%
import pandas as pd

data = {
    'description': [
        # --- Food ---
        'Achat de courses', 'Courses au supermarché', 'Légumes frais', 'Viande et poisson',
        'Dîner au restaurant', 'Buffet du déjeuner', 'Repas fast-food', 'Livraison de pizza',
        'Petit-déjeuner au café', 'Café', 'Produits de boulangerie', 'Glace', 'Snacks',
        'Repas dans la food court', 'Plat à emporter', 'Facture de restaurant', 'Épicerie',
        'Fruits et légumes', 'Produits laitiers', 'Courses hebdomadaires', 'Produits alimentaires',
        "Dîner à l'extérieur", "Repas à l'hôtel", 'Service traiteur', 'Livraison de repas',
        'Ingrédients de cuisine', 'Épices et condiments', 'Achat de boissons', 'Boutique de desserts', 'Street food',
        'Poulet biryani', 'Riz frit', 'Kottu roti', 'Dosa et idli', 'Sandwicherie',
        'Supermarché Cargills', 'Supermarché Keells', 'Supermarché Arpico',
        'Magasin bio', 'Marché de légumes', 'Marché aux poissons', 'Boucherie',
        'Repas dans un food hall', 'Buffet restaurant', 'Repas au café',
        'Bar à salade', 'Petit-déjeuner buffet', 'Tacos à emporter', 'Crêperie', 'Café gourmand',
        'Smoothie frais', 'Bar à sushis', 'Plats végétariens', 'Pâtisserie artisanale', 'Sandwich fait maison',
        'Commande de brunch', 'Achat de produits surgelés', 'Dîner familial', 'Achat de snacks sucrés', 'Achat de boissons chaudes',
        # --- Food END (60 entrées) ---

        # --- Transport ---
        'Course Uber', 'Course de taxi', 'Ticket de bus', 'Billet de train', 'Carte de métro',
        'Station-service', 'Carburant voiture', "Recharge d'essence", 'Diesel', 'Carburant véhicule',
        'Auto rickshaw', 'Service de taxi', 'Transport public', 'Abonnement ferroviaire',
        'Navette aéroport', 'Frais de parking', 'Péages', 'Entretien véhicule',
        'Lavage voiture', 'Réparation vélo', 'Coût transport', 'Frais de trajet',
        'Pass de bus', 'Transport mensuel', 'Covoiturage', 'Tricycle motorisé',
        'Bus longue distance', 'Train express', 'Réservation vol', 'Frais de voyage',
        'Course tuk-tuk', 'Bus CTB', 'Abonnement train saison', 'Péage autoroutier', 'Service véhicule',
        'Taxi longue distance', 'Location de voiture', 'Billet de tram', 'Carburant moto', 'Frais de transport scolaire',
        'Navette entreprise', 'Trajet en ferry', 'Location scooter', 'Frais de parking longue durée', 'Billet de métro touristique',
        # --- Transport END (45 entrées) ---

        # --- Bills ---
        "Facture d'électricité", "Facture d'eau", 'Facture Internet', 'Facture mobile',
        'Recharge téléphone', 'Paiement haut débit', 'Télévision par câble', 'Facture de services',
        'Loyer mensuel', 'Loyer maison', 'Loyer appartement', 'Paiement location',
        'Gaz en bouteille', 'Recharge GPL', 'Paiement électricité', "Frais d'eau",
        'Facture téléphone', 'Facture postpayée', 'Abonnement WiFi', 'Recharge DTH',
        'Charges de maintenance', 'Frais de copropriété', 'Taxe foncière', 'Taxe municipale',
        "Frais d'égout", 'Charges communes', 'Facture puissance', 'Facture énergie',
        'Facture ligne fixe', 'Facture haut débit', 'Abonnement TV', 'Paiement utilité',
        'Cotisations mensuelles', 'Frais de service', 'Entretien bâtiment', 'Facture CEB',
        'Facture water board', 'Facture Dialog mobile', 'Facture SLT fiber', 'Entretien appartement',
        'Facture chauffage', 'Frais de gestion copropriété', 'Abonnement électricité prépayée', 'Facture gaz naturel', 'Frais Internet professionnel',
        'Facture téléphonique entreprise', 'Facture eau chaude', 'Facture sécurité domestique', 'Paiement assurance habitation', 'Abonnement câble premium',
        # --- Bills END (50 entrées) ---

        # --- Entertainment ---
        'Abonnement Netflix', 'Amazon Prime', 'Spotify premium', 'YouTube premium',
        'Billets de cinéma', 'Salle de cinéma', 'Billets de concert', 'Pass événement',
        'Abonnement gaming', 'PlayStation Plus', 'Xbox Game Pass', 'Jeu Steam',
        'Entrée parc à thème', "Parc d'attractions", 'Billet musée', 'Entrée zoo',
        'Événement sportif', 'Match de cricket', 'Match de football', 'Spectacle théâtre',
        'Festival de musique', 'Exposition artistique', 'Frais divertissement', 'Cours hobby', 'Activité fun',
        'Service de streaming', 'Disney Plus', 'HBO Max', 'Jeu vidéo', 'Frais récréation',
        'Billet parc aquatique', 'Abonnement cartoon', 'Billet théâtre musical', 'Concert privé', "Frais d'escape game",
        'Sortie cinéma enfants', 'Billet opéras', 'Abonnement magazine numérique', 'Billet festival local', 'Frais karaoké',
        # --- Entertainment END (40 entrées) ---

        # --- Shopping ---
        'Courses vêtements', 'Nouvelle chemise', 'Achat chaussures', 'Achat robe',
        'Shopping en ligne', 'Commande Amazon', 'Commande Flipkart', 'Magasin électronique',
        'Téléphone portable', 'Achat ordinateur portable', 'Casque audio', 'Accessoires',
        'Achat meubles', 'Décoration maison', 'Articles cuisine', 'Appareils électroménagers',
        'Livres et papeterie', 'Articles cadeaux', 'Cosmétiques', 'Produits soin personnel',
        'Achat bijoux', 'Achat montre', 'Sac et bagages', 'Matériel sport', 'Magasin jouets',
        'Accessoires mode', 'Gadget électronique', 'Electroménager maison', 'Fournitures bureau', 'Vêtements designer',
        'Achat sac à main', 'Achat lunettes', 'Vêtements enfants', 'Achat accessoires cheveux', 'Achat parfum',
        'Achat montre connectée', 'Achat chaussures sport', 'Achat outils bricolage', 'Achat décoration bureau', 'Achat lampe design',
        # --- Shopping END (40 entrées) ---

        # --- Healthcare ---
        'Consultation médecin', 'Bilan médical', 'Tests de laboratoire', 'Analyse sanguine',
        'Facture pharmacie', 'Achat médicaments', 'Médicaments sur ordonnance', 'Compléments santé',
        'Facture hôpital', 'Visite clinique', 'Consultation dentaire', 'Examen de la vue',
        'Physiothérapie', 'Assurance médicale', 'Prime assurance santé', 'Vaccination',
        'Radiographie', 'Scanner CT', 'IRM', 'Procédure médicale',
        'Coût chirurgie', 'Admission hôpital', 'Traitement urgence', 'Premiers soins', 'Coût soins santé',
        'Honoraires médecin', 'Frais hôpital', 'Traitement dentaire', 'Soins yeux', 'Bilan santé',
        'Médicaments pharmacie', 'Coût ordonnance', 'Test médical', 'Dépistage santé', 'Frais clinique',
        'Consultation nutrition', 'Frais kinésithérapie', 'Vaccin annuel', 'Bilans sanguins complets', 'Consultation dermatologie',
        'Traitement physiologique', 'Séance ostéopathie', 'Séance acupuncture', 'Achat inhalateurs', 'Test audiométrique',
        # --- Healthcare END (45 entrées) ---

        # --- Education ---
        'Frais scolaire', 'Frais université', 'Inscription cours', 'Cours en ligne',
        'Cours Udemy', 'Abonnement Coursera', 'Livres et notes', 'Matériel étude',
        'Frais examen', 'Certification', 'Inscription atelier', 'Frais séminaire',
        'Programme formation', 'Frais éducation', 'Plateforme apprentissage',
        'Frais université', 'Livres académiques', 'Cours tutoriels', 'Cours langue', 'Développement compétences',
        'Formation professionnelle', 'Cours métier', 'Programme diplôme', 'Cours diplôme', 'Matériel éducatif',
        'Cours sciences', 'Abonnement plateforme étude', 'Frais laboratoire', 'Cours spécialisation', 'Frais bibliothèque',
        # --- Education END (30 entrées) ---

        # --- Other ---
        'Dépenses diverses', 'Achat aléatoire', 'Don caritatif', 'Offrir cadeau',
        'Nourriture animal', 'Soins animaux', 'Visite salon', 'Coupe de cheveux',
        'Service blanchisserie', 'Nettoyage à sec', 'Photographie', 'Service impression',
        'Frais courrier', 'Postage', 'Dépense générale',
        'Salon beauté', 'Soin spa', 'Service soin', 'Fournitures animaux',
        'Matériel hobby', 'Fournitures artisanat', 'Soin personnel', 'Bien-être', 'Auto-soin',
        'Cours de yoga', 'Frais coiffeur maison', 'Atelier créatif', 'Service jardinage', 'Soin des plantes',
        'Dépense imprévue'
        # --- Other END (30 entrées) ---
    ]
}

# Compte automatique par catégorie
food_count = 60
transport_count = 45
bills_count = 50
entertainment_count = 40
shopping_count = 40
healthcare_count = 45
education_count = 30
other_count = 30

# Génère les catégories
data['categories'] = (
    ['Nourriture'] * food_count +
    ['Transport'] * transport_count +
    ['Factures'] * bills_count +
    ['Divertissement'] * entertainment_count +
    ['Achats'] * shopping_count +
    ['Santé'] * healthcare_count +
    ['Éducation'] * education_count +
    ['Divers'] * other_count
)


df = pd.DataFrame(data)
df.head(100)

# df.to_csv("C:/Users/lenovo/Desktop/file_rouge/data/data.csv")
# Out:
#                     description  categories
# 0              Achat de courses  Nourriture
# 1        Courses au supermarché  Nourriture
# 2                 Légumes frais  Nourriture
# 3             Viande et poisson  Nourriture
# 4           Dîner au restaurant  Nourriture
# ..                          ...         ...
# 95         Taxi longue distance   Transport
# 96          Location de voiture   Transport
# 97               Billet de tram   Transport
# 98               Carburant moto   Transport
# 99  Frais de transport scolaire   Transport
#
# [100 rows x 2 columns]
